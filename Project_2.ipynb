# %%
import pandas as pd
import requests
from sqlalchemy import create_engine
from config import username, pwd

# %%
school_data = pd.read_csv("Public_Schools.csv")
school_data.head()
# Out:
#               X             Y  OBJECTID        NCESID  \
# 0 -9.844095e+06  5.230976e+06         1  170330000017
# 1 -9.007027e+06  4.195442e+06         2  370297001287
# 2 -9.580426e+06  4.792069e+06         3  180369000584
# 3 -1.243297e+07  3.927588e+06         4   40187003479
# 4 -1.243258e+07  3.924831e+06         5   40187003483
#
#                                             NAME             ADDRESS  \
# 0                       ALDEN-HEBRON HIGH SCHOOL    9604 ILLINOIS ST
# 1                         WESTERLY HILLS ACADEMY     4420 DENVER AVE
# 2                    NORTHWOOD ELEMENTARY SCHOOL  965 GRIZZLY CUB DR
# 3  DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL  22700 S. POWER RD.
# 4                DR. CAMILLE CASTEEL HIGH SCHOOL  24901 S. POWER RD.
#
#           CITY STATE    ZIP           ZIP4  ...     VAL_METHOD  \
# 0       HEBRON    IL  60034           9618  ...  IMAGERY/OTHER
# 1    CHARLOTTE    NC  28208           3699  ...  IMAGERY/OTHER
# ...

# %%
income_data = pd.read_csv("IRSIncomeByZipCode.csv")
income_data.head()
# Out:
#   STATE  ZIPCODE  Number of returns  Adjusted gross income (AGI)    Avg AGI  \
# 0    AL        0            2022380                    105089761  51.963410
# 1    AL    35004               4930                       255534  51.832454
# 2    AL    35005               3300                       128387  38.905152
# 3    AL    35006               1230                        58302  47.400000
# 4    AL    35007              11990                       643708  53.687073
#
#    Number of returns with total income  Total income amount  Avg total income  \
# 0                              2022380            106420533         52.621433
# 1                                 4930               258024         52.337525
# 2                                 3300               129390         39.209091
# 3                                 1230                58585         47.630081
# 4                                11990               651350         54.324437
#
# ...

# %%
income_data = income_data.drop(columns=["Adjusted gross income (AGI)","Number of returns with total income","Total income amount","Number of returns with taxable income","Avg taxable income"])
income_data.head()
# Out:
#   STATE  ZIPCODE  Number of returns    Avg AGI  Avg total income  \
# 0    AL        0            2022380  51.963410         52.621433
# 1    AL    35004               4930  51.832454         52.337525
# 2    AL    35005               3300  38.905152         39.209091
# 3    AL    35006               1230  47.400000         47.630081
# 4    AL    35007              11990  53.687073         54.324437
#
#    Taxable income amount
# 0               67850874
# 1                 163859
# 2                  70760
# 3                  36341
# 4                 414878

# %%
#Renaming ZipCODE as Zip
income_data = income_data.rename(columns={"ZIPCODE":"ZIP"})
income_data.head()
# Out:
#   STATE    ZIP  Number of returns    Avg AGI  Avg total income  \
# 0    AL      0            2022380  51.963410         52.621433
# 1    AL  35004               4930  51.832454         52.337525
# 2    AL  35005               3300  38.905152         39.209091
# 3    AL  35006               1230  47.400000         47.630081
# 4    AL  35007              11990  53.687073         54.324437
#
#    Taxable income amount
# 0               67850874
# 1                 163859
# 2                  70760
# 3                  36341
# 4                 414878

# %%
school_data.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'NCESID', 'NAME', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'LEVEL_', 'ENROLLMENT', 'ST_GRADE', 'END_GRADE',
#        'DISTRICTID', 'FT_TEACHER', 'SHELTER_ID'],
#       dtype='object')

# %%
school_data = school_data.drop(columns=["NCESID","ZIP4","STATUS","COUNTYFIPS","NAICS_CODE","NAICS_DESC","SOURCEDATE",
                         "VAL_METHOD","VAL_DATE","DISTRICTID","FT_TEACHER"])

# %%
school_data['TYPE'].replace('1', 'Regular School')
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 102329    1
# 102330    1
# 102331    4
# 102332    1
# 102333    4
# Name: TYPE, Length: 102334, dtype: int64

# %%
school_data.head()
# Out:
#               X             Y  OBJECTID  \
# 0 -9.844095e+06  5.230976e+06         1
# 1 -9.007027e+06  4.195442e+06         2
# 2 -9.580426e+06  4.792069e+06         3
# 3 -1.243297e+07  3.927588e+06         4
# 4 -1.243258e+07  3.924831e+06         5
#
#                                             NAME             ADDRESS  \
# 0                       ALDEN-HEBRON HIGH SCHOOL    9604 ILLINOIS ST
# 1                         WESTERLY HILLS ACADEMY     4420 DENVER AVE
# 2                    NORTHWOOD ELEMENTARY SCHOOL  965 GRIZZLY CUB DR
# 3  DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL  22700 S. POWER RD.
# 4                DR. CAMILLE CASTEEL HIGH SCHOOL  24901 S. POWER RD.
#
#           CITY STATE    ZIP       TELEPHONE  TYPE  ...  COUNTRY   LATITUDE  \
# 0       HEBRON    IL  60034  (815) 648-2442     1  ...      USA  42.465566
# 1    CHARLOTTE    NC  28208  (980) 343-6021     1  ...      USA  35.231909
# 2     FRANKLIN    IN  46131  (317) 346-8900     1  ...      USA  39.489753
# ...

# %%
school_data.dtypes
# Out:
# X             float64
# Y             float64
# OBJECTID        int64
# NAME           object
# ADDRESS        object
# CITY           object
# STATE          object
# ZIP             int64
# TELEPHONE      object
# TYPE            int64
# POPULATION      int64
# COUNTY         object
# COUNTRY        object
# LATITUDE      float64
# LONGITUDE     float64
# SOURCE         object
# WEBSITE        object
# LEVEL_         object
# ENROLLMENT      int64
# ST_GRADE       object
# END_GRADE      object
# SHELTER_ID     object
# dtype: object

# %%
school_data['TYPE'] = school_data['TYPE'].apply(str)

# %%
school_data['TYPE'] = school_data['TYPE'].replace('1', 'Regular School')

# %%
school_data.head()
# Out:
#               X             Y  OBJECTID  \
# 0 -9.844095e+06  5.230976e+06         1
# 1 -9.007027e+06  4.195442e+06         2
# 2 -9.580426e+06  4.792069e+06         3
# 3 -1.243297e+07  3.927588e+06         4
# 4 -1.243258e+07  3.924831e+06         5
#
#                                             NAME             ADDRESS  \
# 0                       ALDEN-HEBRON HIGH SCHOOL    9604 ILLINOIS ST
# 1                         WESTERLY HILLS ACADEMY     4420 DENVER AVE
# 2                    NORTHWOOD ELEMENTARY SCHOOL  965 GRIZZLY CUB DR
# 3  DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL  22700 S. POWER RD.
# 4                DR. CAMILLE CASTEEL HIGH SCHOOL  24901 S. POWER RD.
#
#           CITY STATE    ZIP       TELEPHONE            TYPE  ...  COUNTRY  \
# 0       HEBRON    IL  60034  (815) 648-2442  Regular School  ...      USA
# 1    CHARLOTTE    NC  28208  (980) 343-6021  Regular School  ...      USA
# 2     FRANKLIN    IN  46131  (317) 346-8900  Regular School  ...      USA
# ...

# %%
school_data['TYPE'] = school_data['TYPE'].replace('2', 'Special Education')

# %%
school_data['TYPE'] = school_data['TYPE'].replace('3', 'Vocational')

# %%
school_data['TYPE'] = school_data['TYPE'].replace('4', 'Other/Alternative')

# %%
school_data['TYPE'].unique()
# Out:
# array(['Regular School', 'Other/Alternative', 'Special Education',
#        'Vocational'], dtype=object)

# %%
# Merging the data based on Zipcodes
project_2 = school_data.merge(income_data,how='left',on="ZIP")
project_2
# Out:
#                    X             Y  OBJECTID  \
# 0      -9.844095e+06  5.230976e+06         1
# 1      -9.007027e+06  4.195442e+06         2
# 2      -9.580426e+06  4.792069e+06         3
# 3      -1.243297e+07  3.927588e+06         4
# 4      -1.243258e+07  3.924831e+06         5
# ...              ...           ...       ...
# 102329 -1.075152e+07  5.688108e+06    102330
# 102330 -1.031719e+07  4.598066e+06    102331
# 102331 -8.512030e+06  4.450964e+06    102332
# 102332 -9.024169e+06  4.580376e+06    102333
# 102333 -1.345981e+07  4.856354e+06    102334
#
#                                                  NAME             ADDRESS  \
# 0                            ALDEN-HEBRON HIGH SCHOOL    9604 ILLINOIS ST
# 1                              WESTERLY HILLS ACADEMY     4420 DENVER AVE
# 2                         NORTHWOOD ELEMENTARY SCHOOL  965 GRIZZLY CUB DR
# 3       DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL  22700 S. POWER RD.
# ...

# %%
#Removing unwanted columns from the merged dataset
project_2 = project_2.drop(columns=["SHELTER_ID","STATE_y","X","Y","SOURCE","Number of returns"])
project_2
# Out:
#         OBJECTID                                           NAME  \
# 0              1                       ALDEN-HEBRON HIGH SCHOOL
# 1              2                         WESTERLY HILLS ACADEMY
# 2              3                    NORTHWOOD ELEMENTARY SCHOOL
# 3              4  DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL
# 4              5                DR. CAMILLE CASTEEL HIGH SCHOOL
# ...          ...                                            ...
# 102329    102330                          LISMORE COLONY SCHOOL
# 102330    102331                              OSAGE BEACH ELEM.
# 102331    102332                POINT OPTION ALTERNATIVE SCHOOL
# 102332    102333                            GATEWOOD ELEMENTARY
# 102333    102334                      PLUMAS COUNTY OPPORTUNITY
#
#                    ADDRESS          CITY STATE_x    ZIP       TELEPHONE  \
# 0         9604 ILLINOIS ST        HEBRON      IL  60034  (815) 648-2442
# ...

# %%
project_2 = project_2.rename(columns={"STATE_x":"STATE"})
project_2
# Out:
#         OBJECTID                                           NAME  \
# 0              1                       ALDEN-HEBRON HIGH SCHOOL
# 1              2                         WESTERLY HILLS ACADEMY
# 2              3                    NORTHWOOD ELEMENTARY SCHOOL
# 3              4  DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL
# 4              5                DR. CAMILLE CASTEEL HIGH SCHOOL
# ...          ...                                            ...
# 102329    102330                          LISMORE COLONY SCHOOL
# 102330    102331                              OSAGE BEACH ELEM.
# 102331    102332                POINT OPTION ALTERNATIVE SCHOOL
# 102332    102333                            GATEWOOD ELEMENTARY
# 102333    102334                      PLUMAS COUNTY OPPORTUNITY
#
#                    ADDRESS          CITY STATE    ZIP       TELEPHONE  \
# 0         9604 ILLINOIS ST        HEBRON    IL  60034  (815) 648-2442
# ...

# %%
# Converting dataframe to store as CSV file
project_data = project_2.to_csv("project_data.csv")

# %%
# Load the DataFrame into Postgres Database, Please ensure to run the table schemata sql file before running this part of code
#Create Engine
engine = create_engine(f'postgresql://{username}:{pwd}@localhost/Project_2')

# %%
# Insert into project_data table in SQL
project_2.to_sql(name='project_data',con=engine,if_exists='append',index=False)
